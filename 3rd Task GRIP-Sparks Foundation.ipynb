# %% [markdown]
# #  Data Science and Business Analytics Internship at The Sparks Foundation
# ## Author : Veerendra RV
# ###  Prediction using Decision Tree Algorithm- IRIS Dataset
# ### Problem Statement: *Create the Decision Tree Classifier and Visualize it Graphically The purpose is if we feed any new data to this classifier, it would be able to predcit the right class accordingly*.

# %%
## Importing Standard Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
sns.set_style('darkgrid')
warnings.filterwarnings('ignore')

# %%
## Read The Data
df=pd.read_csv("C:/Users/INDIA/Downloads/iris.csv")

# %%
## View top 5 Rows
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
## View last 5 Rows
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
## Shape of data
df.shape
# Out:
# (150, 6)

# %%
## Data Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
## Statistics of data
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
## Checking for null values
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # Data Visualization and Analysis

# %%
## Checking the value counts for each class in our dataset

df['Species'].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
## Plot a pairplot
df=df.drop('Id',axis=1)
sns.pairplot(df, hue='Species', markers='*')
plt.show()

# %% [markdown]
# # Extracting Features

# %%
## Target variable
y=df['Species']

# %%
## Feature variables
X=df.drop(['Species'],axis=1)
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
## Split the dataset into training and testing data

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=12,stratify=y)

# %% [markdown]
# #  Applying Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)

print('Decision Tree Classifier Created Successfully')
# Out:
# Decision Tree Classifier Created Successfully

# %%
## Prediction
y_pred=dtree.predict(X_test)

# %%
## Importing Confusion Matrix

from sklearn.metrics import confusion_matrix,accuracy_score
confusion_matrix(y_test,y_pred)
# Out:
# array([[15,  0,  0],
#        [ 0, 14,  1],
#        [ 0,  0, 15]], dtype=int64)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9777777777777777

# %% [markdown]
# #  Decision Tree Visualization

# %%
## Importing tree 
from sklearn import tree

# %%
fn=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
cn=['Iris-setosa','Iris-versicolor','Iris-virginica']

fig,axes=plt.subplots(nrows=1, ncols=1, figsize=(4,4),dpi=300)

tree.plot_tree(dtree, feature_names=fn, class_names=cn, filled=True,rounded=True)
plt.show()

# %% [markdown]
# **Now we can able to feed any new test data to this classifer and it would be able to predict the right class accordingly.**

# %% [markdown]
# # Thank You
